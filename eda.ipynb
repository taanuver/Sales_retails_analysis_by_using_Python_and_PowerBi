# %% [markdown]
# Retail Sales EDA

# %% [markdown]
# # import their all libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # upload their CSV file

# %%
df=pd.read_csv("/Users/anuragyadav/Desktop/retail_dataset/retail_sales_dataset.csv")

# %% [markdown]
# # to display their datset in table form

# %%
df.head()
# Out:
#     order_id  order_date customer_id customer_name   age gender   region  \
# 0  ORD-03903  2024-08-15   CUST32603   Aarav Mehta  39.0  Other  Central
# 1  ORD-02198  2022-08-16   CUST07881  Sanjay Verma  28.0   Male     West
# 2  ORD-01348  2021-08-29   CUST49296  Pooja Sharma  41.0  Other     West
# 3  ORD-02076  2022-07-05   CUST05587   Priya Reddy  29.0  Other     West
# 4  ORD-00287  2020-05-07   CUST58035   Ritu Sharma   9.0   Male  Central
#
#         city product_category product_name  ...  unit_price  discount_pct  \
# 0     Raipur        Groceries        Sugar  ...      346.32           NaN
# 1     Mumbai           Beauty    Sunscreen  ...      858.66          0.08
# 2      Surat        Furniture         Sofa  ...    25941.32          0.14
# 3  Ahmedabad        Furniture    Bed Frame  ...    22071.92          0.17
# 4     Nagpur        Groceries  Cooking Oil  ...      320.06          0.31
#
#    sales_amount    profit  shipping_cost  payment_method  \
# ...

# %% [markdown]
# # to find all null/missing values

# %%
df.isnull().sum()
# Out:
# order_id                  30
# order_date                30
# customer_id               30
# customer_name             30
# age                      160
# gender                    30
# region                    30
# city                      30
# product_category          30
# product_name              30
# quantity                 140
# unit_price                30
# discount_pct             167
# sales_amount              30
# profit                    30
# shipping_cost             30
# payment_method            30
# customer_satisfaction    378
# return_flag               30
# order_status              30
# days_to_ship             130
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4310 entries, 0 to 4309
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               4280 non-null   object
#  1   order_date             4280 non-null   object
#  2   customer_id            4280 non-null   object
#  3   customer_name          4280 non-null   object
#  4   age                    4150 non-null   float64
#  5   gender                 4280 non-null   object
#  6   region                 4280 non-null   object
#  7   city                   4280 non-null   object
#  8   product_category       4280 non-null   object
#  9   product_name           4280 non-null   object
#  10  quantity               4170 non-null   float64
#  11  unit_price             4280 non-null   float64
#  12  discount_pct           4143 non-null   float64
#  13  sales_amount           4280 non-null   float64
# ...

# %% [markdown]
# # its all about statistics description

# %%
df.describe()
# Out:
#                age     quantity    unit_price  discount_pct  sales_amount  \
# count  4150.000000  4170.000000   4280.000000   4143.000000  4.280000e+03
# mean     35.335181     7.379856  10621.154428      0.202085  6.235864e+04
# std      35.709382    43.578352  17323.704016      0.118095  3.166998e+05
# min      -7.000000    -1.000000     50.260000      0.000000  3.945000e+01
# 25%      26.000000     3.000000    672.222500      0.100000  2.462165e+03
# 50%      34.000000     5.000000   2228.435000      0.210000  9.548075e+03
# 75%      42.000000     8.000000  12717.435000      0.310000  5.006964e+04
# max     999.000000   999.000000  79957.920000      0.400000  1.736031e+07
#
#              profit  shipping_cost  customer_satisfaction  days_to_ship
# count  4.280000e+03    4280.000000            3932.000000   4180.000000
# mean   1.168713e+04      63.358836               3.016531      5.620335
# std    5.287522e+04      18.312281               1.413127      4.178663
# ...

# %%
before=df.shape[0]

# %%
df=df.dropna(subset=['order_id'])

# %%
after=df.shape[0]

# %%
print("delete rows",before-after)
# Out:
# delete rows 30

# %%
print(df.shape)
# Out:
# (4280, 21)

# %%
df.isnull().sum()
# Out:
# order_id                   0
# order_date                 0
# customer_id                0
# customer_name              0
# age                      130
# gender                     0
# region                     0
# city                       0
# product_category           0
# product_name               0
# quantity                 110
# unit_price                 0
# discount_pct             137
# sales_amount               0
# profit                     0
# shipping_cost              0
# payment_method             0
# customer_satisfaction    348
# return_flag                0
# order_status               0
# days_to_ship             100
# dtype: int64

# %% [markdown]
# # remove their various column

# %%
df.drop(columns=['order_id','customer_id','customer_name'],inplace=True)

# %%
df.columns
# Out:
# Index(['order_date', 'age', 'gender', 'region', 'city', 'product_category',
#        'product_name', 'quantity', 'unit_price', 'discount_pct',
#        'sales_amount', 'profit', 'shipping_cost', 'payment_method',
#        'customer_satisfaction', 'return_flag', 'order_status', 'days_to_ship'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# order_date                 0
# age                      130
# gender                     0
# region                     0
# city                       0
# product_category           0
# product_name               0
# quantity                 110
# unit_price                 0
# discount_pct             137
# sales_amount               0
# profit                     0
# shipping_cost              0
# payment_method             0
# customer_satisfaction    348
# return_flag                0
# order_status               0
# days_to_ship             100
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['days_to_ship'])
plt.show()

# %%
mask1=df['days_to_ship'].isnull()
print(df.loc[mask1,['days_to_ship']])
# Out:
#       days_to_ship
# 13             NaN
# 70             NaN
# 77             NaN
# 164            NaN
# 173            NaN
# ...            ...
# 4001           NaN
# 4057           NaN
# 4132           NaN
# 4181           NaN
# 4196           NaN
#
# [100 rows x 1 columns]

# %%
median_value1=df['days_to_ship'].median()
print("Median value of days_to_ship:", median_value1)
# Out:
# Median value of days_to_ship: 6.0

# %%
mask2=df['days_to_ship'].isnull()
df.loc[mask2,'days_to_ship']=median_value1

# %%
print(df.loc[mask2,['days_to_ship']])
# Out:
#       days_to_ship
# 13             6.0
# 70             6.0
# 77             6.0
# 164            6.0
# 173            6.0
# ...            ...
# 4001           6.0
# 4057           6.0
# 4132           6.0
# 4181           6.0
# 4196           6.0
#
# [100 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['days_to_ship'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['age'])
plt.show()

# %%
df['age'].median()
median_value2=df['age'].median()
print("Median value of age:", median_value2)
# Out:
# Median value of age: 34.0

# %%
mask3=df['age'].isnull()
df.loc[mask3,'age']=median_value2

# %%
print(df.loc[mask3,['age']])
# Out:
#        age
# 62    34.0
# 74    34.0
# 84    34.0
# 96    34.0
# 104   34.0
# ...    ...
# 4120  34.0
# 4133  34.0
# 4153  34.0
# 4269  34.0
# 4295  34.0
#
# [130 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['quantity'])
plt.show()

# %%
df['quantity'].median()
median_value3=df['quantity'].median()
print("Median value of quantity:", median_value3)
# Out:
# Median value of quantity: 5.0

# %%
mask4=df['quantity'].isnull()
df.loc[mask4,'quantity']=median_value3

# %%
print(df.loc[mask4,['quantity']])
# Out:
#       quantity
# 23         5.0
# 37         5.0
# 61         5.0
# 71         5.0
# 76         5.0
# ...        ...
# 4164       5.0
# 4205       5.0
# 4210       5.0
# 4211       5.0
# 4261       5.0
#
# [110 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['discount_pct'])
plt.show()

# %%
df['discount_pct'].mean()
mean_value=df['discount_pct'].mean()
print("Mean value of discount percentage:", mean_value)
# Out:
# Mean value of discount percentage: 0.2020854453294714

# %%
mask5=df['discount_pct'].isnull()
df.loc[mask5,'discount_pct']=mean_value

# %%
print(df.loc[mask5,['discount_pct']])
# Out:
#       discount_pct
# 0         0.202085
# 14        0.202085
# 63        0.202085
# 146       0.202085
# 173       0.202085
# ...            ...
# 4115      0.202085
# 4132      0.202085
# 4256      0.202085
# 4301      0.202085
# 4302      0.202085
#
# [137 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['customer_satisfaction'])
plt.show()

# %%
df['customer_satisfaction'].mean()
mean_value1=df['customer_satisfaction'].mean()
print("Mean value of customer satisfaction:", mean_value1)
# Out:
# Mean value of customer satisfaction: 3.016531027466938

# %%
mask6=df['customer_satisfaction'].isnull()
df.loc[mask6,'customer_satisfaction']=mean_value1

# %%
print(df.loc[mask,['customer_satisfaction']])
# Out:
#       customer_satisfaction
# 23                 2.000000
# 37                 5.000000
# 61                 1.000000
# 71                 1.000000
# 76                 3.016531
# ...                     ...
# 4164               2.000000
# 4205               1.000000
# 4210               2.000000
# 4211               1.000000
# 4261               1.000000
#
# [110 rows x 1 columns]

# %%
df.to_csv('retail_sales_dataset_clean.csv', index=False)
